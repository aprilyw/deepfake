# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow import keras
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Input
from tensorflow.keras.models import Model

# %%
#kyle = np.load('drive/My Drive/kyles.npy')
tyler = np.load('drive/My Drive/tyler.npy')
cage = np.load('drive/My Drive/cages.npy')

# %%
## encoder
e1 = keras.layers.Conv2D(16,(3,3),activation='relu', padding='same', input_shape=(175,175,3))
#e1.trainable=False

e2 = keras.layers.MaxPooling2D((2,2), padding='same')
#e2.trainable=False

e3 = keras.layers.Conv2D(32,(3,3), activation='relu', padding='same')
#e3.trainable=False

e4 = keras.layers.MaxPooling2D((2,2), padding='same')
#e4.trainable=False

e5 = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')
#e5.trainable=False

## latent face
core = keras.layers.MaxPooling2D((2,2), padding='same')
#core.trainable=False


##decoder
d1 = keras.layers.Conv2D(64,(3,3),activation='relu', padding='same', input_shape=(22, 22, 64))
d2 = keras.layers.UpSampling2D((2,2))
d3 = keras.layers.Conv2D(32,(3,3), activation='relu', padding='same')
d4 = keras.layers.UpSampling2D((2,2))
d5 = keras.layers.Conv2D(16,(3,3), activation='relu', padding='same')
d6 = keras.layers.UpSampling2D((2,2))

out = keras.layers.Conv2D(3,(2,2), activation='sigmoid', padding='valid')


## add layers to sequential model
# model = keras.Sequential()
# model.add(e1)
# model.add(e2)
# model.add(e3)
# model.add(e4)
# model.add(e5)
# model.add(core)


# model.add(d1)
# model.add(d2)
# model.add(d3)
# model.add(d4)
# model.add(d5)
# model.add(d6)
# model.add(out)

def encoder():
  model = keras.Sequential()
  model.add(e1)
  model.add(e2)
  model.add(e3)
  model.add(e4)
  model.add(e5)
  model.add(core)
  return model

def decoder():
  model = keras.Sequential()
  model.add(d1)
  model.add(d2)
  model.add(d3)
  model.add(d4)
  model.add(d5)
  model.add(d6)
  model.add(out)
  return model
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 21:19:48.593864 140152871487360 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
encoder = encoder()
decoder = decoder()

model = keras.Sequential()
model.add(encoder)
model.add(decoder)

# %%
encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 175, 175, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 88, 88, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 88, 88, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 44, 44, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# =================================================================
# Total params: 23,584
# Trainable params: 23,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 22, 64)        36928
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 44, 44, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 44, 44, 32)        18464
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 88, 88, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 88, 88, 16)        4624
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 176, 176, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 175, 175, 3)       195
# =================================================================
# Total params: 60,211
# Trainable params: 60,211
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 22, 22, 64)        23584
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 175, 175, 3)       60211
# =================================================================
# Total params: 83,795
# Trainable params: 83,795
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(tyler,tyler,epochs=100,batch_size=100)
# Out:
# Epoch 1/100
# 1789/1789 [==============================] - 10s 5ms/sample - loss: 0.0477
# Epoch 2/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0194
# Epoch 3/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0085
# Epoch 4/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0062
# Epoch 5/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0051
# Epoch 6/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0046
# Epoch 7/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0040
# Epoch 8/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0038
# Epoch 9/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0035
# Epoch 10/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0034
# Epoch 11/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0032
# Epoch 12/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0031
# Epoch 13/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0029
# Epoch 14/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0033
# Epoch 15/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0033
# Epoch 16/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0027
# Epoch 17/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0026
# Epoch 18/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0025
# Epoch 19/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0024
# Epoch 20/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0029
# Epoch 21/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0026
# Epoch 22/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0023
# Epoch 23/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0023
# Epoch 24/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0022
# Epoch 25/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0022
# Epoch 26/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0021
# Epoch 27/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0022
# Epoch 28/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0021
# Epoch 29/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0021
# Epoch 30/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0020
# Epoch 31/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0021
# Epoch 32/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0020
# Epoch 33/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0020
# Epoch 34/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0020
# Epoch 35/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0019
# Epoch 36/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0019
# Epoch 37/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0019
# Epoch 38/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0019
# Epoch 39/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0019
# Epoch 40/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0018
# Epoch 41/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0018
# Epoch 42/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0019
# Epoch 43/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0018
# Epoch 44/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0018
# Epoch 45/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0018
# Epoch 46/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0018
# Epoch 47/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0017
# Epoch 48/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0017
# Epoch 49/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0017
# Epoch 50/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0017
# Epoch 51/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0018
# Epoch 52/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0017
# Epoch 53/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 54/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0017
# Epoch 55/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 56/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 57/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 58/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 59/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 60/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 61/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 62/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 63/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0016
# Epoch 64/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 65/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 66/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 67/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 68/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 69/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 70/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 71/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 72/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 73/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 74/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 75/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 76/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 77/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0015
# Epoch 78/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 79/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 80/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 81/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 82/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 83/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 84/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 85/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 86/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 87/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 88/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 89/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 90/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 91/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 92/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 93/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 94/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 95/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 96/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 97/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 98/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 99/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013
# Epoch 100/100
# 1789/1789 [==============================] - 6s 3ms/sample - loss: 0.0013

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(model.predict(np.array([tyler[850]]))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
encoder.save_weights('drive/My Drive/tyler_encoder1.h5')

# %%
decoder.save_weights('drive/My Drive/tyler_decoder1.h5')

# %%
encoder.load_weights('drive/My Drive/tyler_encoder1.h5')

# %%
decoder.load_weights('drive/My Drive/tyler_decoder1.h5')

# %%
plt.imshow(cv2.cvtColor(decoder.predict(encoder.predict(np.array([tyler[850]])))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
cage_encoded = encoder.predict(cage)

# %%
decoder.compile(optimizer='adam', loss='mse')
decoder.fit(cage_encoded, cage, epochs=100, batch_size=100)
# Out:
# Epoch 1/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0072
# Epoch 2/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0031
# Epoch 3/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0023
# Epoch 4/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0019
# Epoch 5/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0017
# Epoch 6/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0016
# Epoch 7/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 8/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 9/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 10/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 11/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 12/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 13/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 14/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 15/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 16/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 17/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 18/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 19/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 20/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 21/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 22/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 23/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 24/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 25/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 26/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 27/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 28/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 29/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 30/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0010
# Epoch 31/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0010
# Epoch 32/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0010
# Epoch 33/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0010
# Epoch 34/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0010
# Epoch 35/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0010
# Epoch 36/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.9946e-04
# Epoch 37/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 0.0010
# Epoch 38/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.8938e-04
# Epoch 39/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.9034e-04
# Epoch 40/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.8367e-04
# Epoch 41/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.8610e-04
# Epoch 42/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.6696e-04
# Epoch 43/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.6053e-04
# Epoch 44/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.5881e-04
# Epoch 45/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.6601e-04
# Epoch 46/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.6104e-04
# Epoch 47/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.5259e-04
# Epoch 48/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.4198e-04
# Epoch 49/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.3888e-04
# Epoch 50/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.4894e-04
# Epoch 51/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.3668e-04
# Epoch 52/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.2505e-04
# Epoch 53/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.2026e-04
# Epoch 54/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.3083e-04
# Epoch 55/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.1917e-04
# Epoch 56/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.1407e-04
# Epoch 57/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.1372e-04
# Epoch 58/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.1621e-04
# Epoch 59/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.0134e-04
# Epoch 60/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.0570e-04
# Epoch 61/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 9.2257e-04
# Epoch 62/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.9601e-04
# Epoch 63/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.9105e-04
# Epoch 64/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.8721e-04
# Epoch 65/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.9713e-04
# Epoch 66/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.9154e-04
# Epoch 67/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.8363e-04
# Epoch 68/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.8126e-04
# Epoch 69/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.7411e-04
# Epoch 70/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.9079e-04
# Epoch 71/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.7590e-04
# Epoch 72/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.6839e-04
# Epoch 73/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.8006e-04
# Epoch 74/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.7799e-04
# Epoch 75/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.6738e-04
# Epoch 76/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.6323e-04
# Epoch 77/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.5295e-04
# Epoch 78/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.5094e-04
# Epoch 79/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.6329e-04
# Epoch 80/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.5688e-04
# Epoch 81/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.4996e-04
# Epoch 82/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.4614e-04
# Epoch 83/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.4285e-04
# Epoch 84/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.6402e-04
# Epoch 85/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.4778e-04
# Epoch 86/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.5518e-04
# Epoch 87/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.4168e-04
# Epoch 88/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.3443e-04
# Epoch 89/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.2832e-04
# Epoch 90/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.4901e-04
# Epoch 91/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.3697e-04
# Epoch 92/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.2745e-04
# Epoch 93/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.2292e-04
# Epoch 94/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.1888e-04
# Epoch 95/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.3242e-04
# Epoch 96/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.2009e-04
# Epoch 97/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.1882e-04
# Epoch 98/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.3687e-04
# Epoch 99/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.1280e-04
# Epoch 100/100
# 1516/1516 [==============================] - 3s 2ms/sample - loss: 8.1169e-04

# %%
plt.imshow(cv2.cvtColor(decoder.predict(encoder.predict(np.array([cage[850]])))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(decoder.predict(encoder.predict(np.array([tyler[850]])))[0],cv2.COLOR_BGR2RGB))
plt.show()
