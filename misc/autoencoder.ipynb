# %%
keras.backend.clear_session()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from tensorflow import keras
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Input
from tensorflow.keras.models import Model

# %%
kyle = np.load('drive/My Drive/kyles.npy')
tyler = np.load('drive/My Drive/tyler.npy')

# %%
## encoder
e1 = keras.layers.Conv2D(16,(3,3),activation='relu', padding='same', input_shape=(175,175,3))
#e1.trainable=False

e2 = keras.layers.MaxPooling2D((2,2), padding='same')
#e2.trainable=False

e3 = keras.layers.Conv2D(32,(3,3), activation='relu', padding='same')
#e3.trainable=False

e4 = keras.layers.MaxPooling2D((2,2), padding='same')
#e4.trainable=False

e5 = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')
#e5.trainable=False

## latent face
core = keras.layers.MaxPooling2D((2,2), padding='same')
#core.trainable=False


##decoder
d1 = keras.layers.Conv2D(64,(3,3),activation='relu', padding='same', input_shape=(22, 22, 64))
d2 = keras.layers.UpSampling2D((2,2))
d3 = keras.layers.Conv2D(32,(3,3), activation='relu', padding='same')
d4 = keras.layers.UpSampling2D((2,2))
d5 = keras.layers.Conv2D(16,(3,3), activation='relu', padding='same')
d6 = keras.layers.UpSampling2D((2,2))

out = keras.layers.Conv2D(3,(2,2), activation='sigmoid', padding='valid')


## add layers to sequential model
# model = keras.Sequential()
# model.add(e1)
# model.add(e2)
# model.add(e3)
# model.add(e4)
# model.add(e5)
# model.add(core)


# model.add(d1)
# model.add(d2)
# model.add(d3)
# model.add(d4)
# model.add(d5)
# model.add(d6)
# model.add(out)

def encoder():
  model = keras.Sequential()
  model.add(e1)
  model.add(e2)
  model.add(e3)
  model.add(e4)
  model.add(e5)
  model.add(core)
  return model

def decoder():
  model = keras.Sequential()
  model.add(d1)
  model.add(d2)
  model.add(d3)
  model.add(d4)
  model.add(d5)
  model.add(d6)
  model.add(out)
  return model

# %%
encoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 175, 175, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 88, 88, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 88, 88, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 44, 44, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 22, 22, 64)        0
# =================================================================
# Total params: 23,584
# Trainable params: 23,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 44, 44, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 44, 44, 32)        18464
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 88, 88, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 88, 88, 16)        4624
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 176, 176, 16)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 175, 175, 3)       195
# =================================================================
# Total params: 60,211
# Trainable params: 60,211
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder = encoder()
decoder = decoder()

model = keras.Sequential()
model.add(encoder)
model.add(decoder)

# %%
trainable = False
layers = [e1, e2, e3, e4, e5, core]

if (trainable == False):
  for l in layers:
    l.trainable = False
else:
  l.trainable = True

# %%
e1.get_config()
# Out:
# {'activation': 'relu',
#  'activity_regularizer': None,
#  'batch_input_shape': (None, 175, 175, 3),
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {'dtype': 'float32'}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 16,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#   'config': {'dtype': 'float32', 'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv2d',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_3 (Sequential)    (None, 22, 22, 64)        23584
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 175, 175, 3)       60211
# =================================================================
# Total params: 83,795
# Trainable params: 83,795
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(kyle,kyle,epochs=100,batch_size=100)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 6s 6ms/sample - loss: 0.0166
# Epoch 2/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0124
# Epoch 3/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0090
# Epoch 4/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0066
# Epoch 5/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0051
# Epoch 6/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0041
# Epoch 7/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0037
# Epoch 8/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0033
# Epoch 9/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0031
# Epoch 10/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0030
# Epoch 11/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0029
# Epoch 12/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0027
# Epoch 13/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0025
# Epoch 14/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0025
# Epoch 15/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0024
# Epoch 16/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0023
# Epoch 17/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0023
# Epoch 18/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0023
# Epoch 19/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0022
# Epoch 20/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0021
# Epoch 21/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0021
# Epoch 22/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0020
# Epoch 23/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0022
# Epoch 24/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0021
# Epoch 25/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0020
# Epoch 26/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0020
# Epoch 27/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0019
# Epoch 28/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0019
# Epoch 29/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0021
# Epoch 30/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0019
# Epoch 31/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0019
# Epoch 32/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0018
# Epoch 33/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0018
# Epoch 34/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0018
# Epoch 35/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0019
# Epoch 36/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0019
# Epoch 37/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0018
# Epoch 38/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0017
# Epoch 39/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0017
# Epoch 40/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0017
# Epoch 41/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0017
# Epoch 42/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0017
# Epoch 43/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0016
# Epoch 44/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0017
# Epoch 45/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0016
# Epoch 46/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0016
# Epoch 47/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0016
# Epoch 48/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0017
# Epoch 49/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0016
# Epoch 50/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0016
# Epoch 51/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 52/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 53/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0016
# Epoch 54/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 55/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 56/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 57/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 58/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 59/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 60/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 61/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 62/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 63/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 64/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 65/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 66/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 67/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 68/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 69/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 70/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 71/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 72/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 73/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 74/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 75/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 76/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 77/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 78/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 79/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 80/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 81/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0014
# Epoch 82/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 83/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 84/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 85/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 86/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 87/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 88/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 89/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0015
# Epoch 90/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 91/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 92/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 93/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 94/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 95/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 96/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 97/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 98/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 99/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013
# Epoch 100/100
# 1000/1000 [==============================] - 3s 3ms/sample - loss: 0.0013

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(model.predict(np.array([kyle[850]]))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(model.predict(np.array([tyler[850]]))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
np.save('kyle_weights.npy', weights)

# %%
np.save('tyler_weights.npy', weights)

# %%
model.save_weights('tyler_weights.h5')

#drive/My Drive/

# %%
encoder.save_weights('drive/My Drive/kyle_encoder.h5')

# %%
decoder.save_weights('drive/My Drive/kyle_decoder.h5')

# %%
encoder.load_weights('drive/My Drive/kyle_encoder.h5')

# %%
decoder.load_weights('drive/My Drive/kyle_decoder.h5')

# %%
plt.imshow(cv2.cvtColor(decoder.predict(encoder.predict(np.array([kyle[850]])))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
tyler_encoded = encoder.predict(tyler)

# %%
decoder.compile(optimizer='adam', loss='mse')
decoder.fit(tyler_encoded, tyler, epochs=100, batch_size=100)
# Out:
# Epoch 1/100
# 1789/1789 [==============================] - 4s 2ms/sample - loss: 0.0048
# Epoch 2/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0029
# Epoch 3/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0025
# Epoch 4/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0024
# Epoch 5/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0023
# Epoch 6/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0022
# Epoch 7/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0021
# Epoch 8/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0020
# Epoch 9/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0019
# Epoch 10/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0019
# Epoch 11/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0018
# Epoch 12/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0018
# Epoch 13/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0018
# Epoch 14/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0017
# Epoch 15/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0017
# Epoch 16/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0017
# Epoch 17/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0016
# Epoch 18/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0016
# Epoch 19/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0016
# Epoch 20/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0016
# Epoch 21/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0016
# Epoch 22/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 23/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 24/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 25/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 26/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 27/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 28/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0015
# Epoch 29/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 30/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 31/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 32/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 33/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 34/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 35/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 36/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 37/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 38/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0014
# Epoch 39/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 40/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 41/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 42/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 43/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 44/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 45/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 46/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 47/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 48/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 49/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 50/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 51/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 52/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0013
# Epoch 53/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 54/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 55/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 56/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 57/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 58/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 59/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 60/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 61/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 62/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 63/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 64/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 65/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 66/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 67/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 68/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 69/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 70/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 71/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 72/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 73/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 74/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 75/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 76/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 77/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0012
# Epoch 78/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 79/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 80/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 81/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 82/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 83/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 84/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 85/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 86/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 87/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 88/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 89/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 90/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 91/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 92/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 93/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 94/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 95/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 96/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 97/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 98/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 99/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011
# Epoch 100/100
# 1789/1789 [==============================] - 3s 2ms/sample - loss: 0.0011

# %%
plt.imshow(cv2.cvtColor(decoder.predict(encoder.predict(np.array([tyler[850]])))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(decoder.predict(encoder.predict(np.array([kyle[850]])))[0],cv2.COLOR_BGR2RGB))
plt.show()

# %%
decoder.save_weights('drive/My Drive/tyler_decoder.h5')

# %% [markdown]
# load and repiece together models

# %%
e1.get_config()
# Out:
# {'activation': 'relu',
#  'activity_regularizer': None,
#  'batch_input_shape': (None, 175, 175, 3),
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {'dtype': 'float32'}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 16,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#   'config': {'dtype': 'float32', 'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv2d_21',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': False,
#  'use_bias': True}

# %%
encoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 175, 175, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 88, 88, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 88, 88, 8)         1160
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 44, 44, 8)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 44, 44, 8)         584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 22, 22, 8)         0
# =================================================================
# Total params: 2,192
# Trainable params: 0
# Non-trainable params: 2,192
# _________________________________________________________________

# %%
encoder.load_weights('drive/My Drive/tyler_encoder.h5')

# %%
decoder.load_weights('drive/My Drive/kyle_decoder.h5')

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(model.predict(np.array([tyler[850]]))[0],cv2.COLOR_BGR2RGB))
plt.show()
